# %% [markdown]
# # **Theory Questions**
#
# ### Q1. What is a random variable in probability theory?
# A random variable is a numerical outcome of a random phenomenon. It is a function that assigns a real number to each outcome in a sample space. Random variables can be classified into two main types: discrete and continuous.
#
# ### Q2. What are the types of random variables?
# There are two main types of random variables:
# 1. **Discrete Random Variables**: These take on a countable number of distinct values (e.g., the number of heads in a series of coin flips).
# 2. **Continuous Random Variables**: These can take on any value within a given range (e.g., the height of individuals).
#
# ### Q3. What is the difference between discrete and continuous distributions?
# - **Discrete Distributions**: These describe the probabilities of discrete random variables. The probability mass function (PMF) is used to specify the probability of each possible value.
# - **Continuous Distributions**: These describe the probabilities of continuous random variables. The probability density function (PDF) is used, and probabilities are found over intervals rather than at specific points.
#
# ### Q4. What are probability distribution functions (PDF)?
# A probability distribution function (PDF) describes the likelihood of a random variable taking on a particular value. For continuous random variables, the PDF is a function that must satisfy the following properties:
# - The PDF is non-negative: \$f(x) \geq 0\$ for all \$x\$.
# - The area under the PDF curve over the entire space is equal to 1: \$$\int_{-\infty}^{\infty} f(x) \, dx = 1\$$.
#
# ### Q5. How do cumulative distribution functions (CDF) differ from probability distribution functions (PDF)?
# The cumulative distribution function (CDF) gives the probability that a random variable is less than or equal to a certain value. It is defined as:
# \$$
# F(x) = P(X \leq x)
# \$$
# The CDF is the integral of the PDF for continuous random variables:
# \$$
# F(x) = \int_{-\infty}^{x} f(t) \, dt
# \$$
# In contrast, the PDF provides the probability density at a specific point.
#
# ### Q6. What is a discrete uniform distribution?
# A discrete uniform distribution is a probability distribution where a finite number of outcomes are equally likely. For example, when rolling a fair die, each of the six outcomes has a probability of \$\frac{1}{6}\$.
#
# ### Q7. What are the key properties of a Bernoulli distribution?
# The Bernoulli distribution models a single trial with two possible outcomes: success (1) and failure (0). Key properties include:
# - The probability of success is \$p\$ and the probability of failure is \$1 - p\$.
# - The mean (expected value) is \$E[X] = p\$.
# - The variance is \$Var(X) = p(1 - p)\$.
#
# ### Q8. What is the binomial distribution, and how is it used in probability?
# The binomial distribution models the number of successes in a fixed number of independent Bernoulli trials. It is defined by two parameters: the number of trials \$n\$ and the probability of success \$p\$. The probability mass function is given by:
# \$$
# P(X = k) = \binom{n}{k} p^k (1 - p)^{n - k}
# \$$
# for \$k = 0, 1, 2, \ldots, n\$.
#
# ### Q9. What is the Poisson distribution and where is it applied?
# The Poisson distribution models the number of events occurring in a fixed interval of time or space, given that these events occur with a known constant mean rate and independently of the time since the last event. It is defined by the parameter \$\lambda\$, which is the average number of events in the interval. The probability mass function is:
# \$$
# P(X = k) = \frac{\lambda^k e^{-\lambda}}{k!}
# \$$
#
# ### Q10. What is a continuous uniform distribution?
# A continuous uniform distribution is a probability distribution where all outcomes in a given interval are equally likely. The PDF is constant over the interval \([a, b]\) and is defined as:
# \$$
# f(x) = \frac{1}{b - a} \quad \text{for } a \leq x \leq b
# \$$
#
# ### Q11. What are the characteristics of a normal distribution?
# The normal distribution is characterized by its bell-shaped curve, defined by two parameters: the mean (\$\mu\$) and the standard deviation (\$\sigma\$). Key properties include:
# - Symmetry around the mean.
# - The total area under the curve equals 1.
# - Approximately 68% of the data falls within one standard deviation of the mean, 95% within two, and 99.7% within three (the empirical rule).
#
# ### Q12. What is the standard normal distribution, and why is it important?
# The standard normal distribution is a special case of the normal distribution with a mean of 0 and a standard deviation of 1. It is important because it allows for the standardization of normal random variables, enabling the use of Z-scores to compare different normal distributions.
#
# ### Q13. What is the Central Limit Theorem (CLT), and why is it critical in statistics?
# The Central Limit Theorem states that the distribution of the sample mean of a sufficiently large number of independent random variables, regardless of the original distribution, will approximate a normal distribution. This is critical because it allows for the use of normal probability techniques in inferential statistics.
#
# ### Q14. How does the Central Limit Theorem relate to the normal distribution?
# The CLT implies that as the sample size increases, the sampling distribution of the sample mean approaches a normal distribution, even if the original population distribution is not normal. This property is fundamental for hypothesis testing and confidence interval estimation.
#
# ### Q15. What is the application of Z statistics in hypothesis testing?
# Z statistics are used in hypothesis testing to determine how far a sample mean is from the population mean in terms of standard deviations. It helps in deciding whether to reject the null hypothesis based on the calculated Z-score and the significance level.
#
# ### Q16. How do you calculate a Z-score, and what does it represent?
# A Z-score is calculated using the formula:
# \$$
# Z = \frac{X - \mu}{\sigma}
# \$$
# where \$X\$ is the value, \$\mu\$ is the mean, and \$\sigma\$ is the standard deviation. The Z-score represents the number of standard deviations a data point is from the mean.
#
# ### Q17. What are point estimates and interval estimates in statistics?
# - **Point Estimate**: A single value that serves as an estimate of a population parameter (e.g., sample mean).
# - **Interval Estimate**: A range of values, derived from the sample data, that is likely to contain the population parameter (e.g., confidence interval).
#
# ### Q18. What is the significance of confidence intervals in statistical analysis?
# Confidence intervals provide a range of values within which we can be reasonably certain that a population parameter lies. They quantify the uncertainty associated with point estimates and are crucial for making inferences about populations.
#
# ### Q19. What is the relationship between a Z-score and a confidence interval?
# A Z-score is used to determine the critical values that define the boundaries of a confidence interval. For example, a 95% confidence interval corresponds to Z-scores of approximately -1.96 and +1.96.
#
# ### Q20. How are Z-scores used to compare different distributions?
# Z-scores standardize different distributions, allowing for comparison on a common scale. By converting raw scores to Z-scores, we can assess how far and in what direction a score deviates from the mean, regardless of the original distribution's scale.
#
# ### Q21. What are the assumptions for applying the Central Limit Theorem?
# The assumptions for the CLT include:
# 1. The samples must be independent.
# 2. The sample size should be sufficiently large (typically n ≥ 30 is considered adequate).
# 3. The population from which samples are drawn should have a finite mean and variance.
#
# ### Q22. What is the concept of expected value in a probability distribution?
# The expected value (or mean) of a random variable is a measure of the central tendency of its probability distribution. It is calculated as:
# - For discrete random variables: \$$E[X] = \sum_{i} x_i P(X = x_i)\$$
# - For continuous random variables: \$$E[X] = \int_{-\infty}^{\infty} x f(x) \, dx\$$
#
# ### Q23. How does a probability distribution relate to the expected outcome of a random variable?
# A probability distribution provides the probabilities of all possible outcomes of a random variable, and the expected value represents the long-term average or mean outcome if the experiment were repeated many times. The expected value is a weighted average of all possible values, where the weights are the probabilities of each outcome.

# %% [markdown]
# # **Practical Questions**

# %%
# Q1: Generate a random variable and display its value
import random
random_variable = random.random()  # Generates a random float between 0 and 1
print("Random Variable:", random_variable)
# Out:
# Random Variable: 0.40021632225236836

# %%
# Q2: Generate a discrete uniform distribution and plot the PMF
import numpy as np
import matplotlib.pyplot as plt
n = 10  # Number of outcomes
pmf = np.ones(n) / n  # PMF for discrete uniform distribution
x = np.arange(1, n + 1)
plt.bar(x, pmf)
plt.title('Probability Mass Function (PMF) of Discrete Uniform Distribution')
plt.xlabel('Outcomes')
plt.ylabel('Probability')
plt.xticks(x)
plt.show()

# %%
# Q3: Calculate the PDF of a Bernoulli distribution
def bernoulli_pdf(p, x):
    return p if x == 1 else (1 - p)
# Example usage
p = 0.5
x_values = [0, 1]
pdf_values = [bernoulli_pdf(p, x) for x in x_values]
print("Bernoulli PDF values:", pdf_values)
# Out:
# Bernoulli PDF values: [0.5, 0.5]

# %%
# Q4: Simulate a binomial distribution and plot its histogram
from scipy.stats import binom
n = 10
p = 0.5
data = binom.rvs(n, p, size=1000)
plt.hist(data, bins=np.arange(-0.5, n + 1.5, 1), density=True, alpha=0.6, color='g')
plt.title('Histogram of Binomial Distribution (n=10, p=0.5)')
plt.xlabel('Number of Successes')
plt.ylabel('Probability')
plt.xticks(range(n + 1))
plt.show()

# %%
# Q5: Create a Poisson distribution and visualize it
from scipy.stats import poisson
lambda_ = 3  # Average rate (lambda)
x = np.arange(0, 10)
pmf = poisson.pmf(x, lambda_)
plt.bar(x, pmf)
plt.title('Poisson Distribution (λ=3)')
plt.xlabel('Number of Events')
plt.ylabel('Probability')
plt.show()

# %%
# Q6: Calculate and plot the CDF of a discrete uniform distribution
cdf = np.cumsum(pmf)
plt.step(x, cdf, where='post')
plt.title('Cumulative Distribution Function (CDF) of Discrete Uniform Distribution')
plt.xlabel('Outcomes')
plt.ylabel('Cumulative Probability')
plt.xticks(x)
plt.show()

# %%
# Q7: Generate a continuous uniform distribution and visualize it
a, b = 0, 1  # Interval [a, b]
data = np.random.uniform(a, b, 1000)
plt.hist(data, bins=30, density=True, alpha=0.6, color='b')
plt.title('Continuous Uniform Distribution')
plt.xlabel('Value')
plt.ylabel('Density')
plt.show()

# %%
# Q8: Simulate data from a normal distribution and plot its histogram
mu, sigma = 0, 1  # Mean and standard deviation
data = np.random.normal(mu, sigma, 1000)
plt.hist(data, bins=30, density=True, alpha=0.6, color='r')
plt.title('Normal Distribution (μ=0, σ=1)')
plt.xlabel('Value')
plt.ylabel('Density')
plt.show()

# %%
# Q9: Calculate Z-scores from a dataset and plot them
def calculate_z_scores(data):
    mean = np.mean(data)
    std_dev = np.std(data)
    z_scores = (data - mean) / std_dev
    return z_scores
data = np.random.normal(0, 1, 1000)
z_scores = calculate_z_scores(data)
plt.hist(z_scores, bins=30, density=True, alpha=0.6, color='purple')
plt.title('Z-Scores Distribution')
plt.xlabel('Z-Score')
plt.ylabel('Density')
plt.show()

# %%
# Q10: Implement the Central Limit Theorem (CLT) for a non-normal distribution
non_normal_data = np.random.exponential(scale=2, size=1000)
sample_means = [np.mean(np.random.choice(non_normal_data, size=30)) for _ in range(1000)]
plt.hist(sample_means, bins=30, density=True, alpha=0.6, color='orange')
plt.title('Sampling Distribution of the Mean (CLT)')
plt.xlabel('Sample Mean')
plt.ylabel('Density')
plt.show()

# %%
# Q11: Simulate multiple samples from a normal distribution and verify the CLT
sample_means = [np.mean(np.random.normal(0, 1, 30)) for _ in range(1000)]
plt.hist(sample_means, bins=30, density=True, alpha=0.6, color='cyan')
plt.title('Sampling Distribution of the Mean (CLT Verification)')
plt.xlabel('Sample Mean')
plt.ylabel('Density')
plt.show()

# %%
# Q12: Calculate and plot the standard normal distribution
def standard_normal_pdf(x):
    return (1 / np.sqrt(2 * np.pi)) * np.exp(-0.5 * x**2)
x = np.linspace(-4, 4, 100)
y = standard_normal_pdf(x)
plt.plot(x, y)
plt.title('Standard Normal Distribution (μ=0, σ=1)')
plt.xlabel('Z-Score')
plt.ylabel('Density')
plt.grid()
plt.show()

# %%
# Q13: Generate random variables and calculate their probabilities using the binomial distribution
n = 10
p = 0.5
k = np.arange(0, n + 1)
probabilities = binom.pmf(k, n, p)
print("Binomial probabilities for k=0 to n=10:", probabilities)
# Out:
# Binomial probabilities for k=0 to n=10: [0.00097656 0.00976563 0.04394531 0.1171875  0.20507812 0.24609375
#  0.20507812 0.1171875  0.04394531 0.00976563 0.00097656]

# %%
# Q14: Calculate the Z-score for a given data point and compare it to a standard normal distribution
data_point = 1.5
z_score = (data_point - mu) / sigma
print("Z-score for data point", data_point, "is", z_score)
# Out:
# Z-score for data point 1.5 is 1.5

# %%
# Q15: Implement hypothesis testing using Z-statistics for a sample dataset
sample_data = np.random.normal(5, 1, 30)
sample_mean = np.mean(sample_data)
sample_std = np.std(sample_data)
n = len(sample_data)
z_statistic = (sample_mean - 5) / (sample_std / np.sqrt(n))
print("Z-statistic:", z_statistic)
# Out:
# Z-statistic: 2.0123187298365224

# %%
# Q16: Create a confidence interval for a dataset using Python and interpret the result
confidence_level = 0.95
z_critical = 1.96  # For 95% confidence
margin_of_error = z_critical * (sample_std / np.sqrt(n))
confidence_interval = (sample_mean - margin_of_error, sample_mean + margin_of_error)
print("Confidence Interval:", confidence_interval)
# Out:
# Confidence Interval: (np.float64(5.010739369378795), np.float64(5.815390554459539))

# %%
# Q17: Generate data from a normal distribution, then calculate and interpret the confidence interval for its mean
data = np.random.normal(10, 2, 100)
mean = np.mean(data)
std = np.std(data)
n = len(data)
margin_of_error = z_critical * (std / np.sqrt(n))
confidence_interval = (mean - margin_of_error, mean + margin_of_error)
print("Confidence Interval for the mean:", confidence_interval)
# Out:
# Confidence Interval for the mean: (np.float64(9.489864427633288), np.float64(10.289403533651262))

# %%
# Q18: Calculate and visualize the PDF of a normal distribution
x = np.linspace(-4, 4, 100)
pdf = (1 / (sigma * np.sqrt(2 * np.pi))) * np.exp(-0.5 * ((x - mu) / sigma) ** 2)
plt.plot(x, pdf)
plt.title('Probability Density Function (PDF) of Normal Distribution')
plt.xlabel('Value')
plt.ylabel('Density')
plt.grid()
plt.show()

# %%
# Q19: Calculate and interpret the CDF of a Poisson distribution
lambda_ = 3
x = np.arange(0, 10)
cdf = poisson.cdf(x, lambda_)
plt.step(x, cdf, where='post')
plt.title('Cumulative Distribution Function (CDF) of Poisson Distribution')
plt.xlabel('Number of Events')
plt.ylabel('Cumulative Probability')
plt.show()

# %%
# Q20: Simulate a random variable using a continuous uniform distribution and calculate its expected value
a, b = 0, 1
random_variable = np.random.uniform(a, b)
expected_value = (a + b) / 2
print("Random Variable:", random_variable)
print("Expected Value of Continuous Uniform Distribution:", expected_value)
# Out:
# Random Variable: 0.37473578647723116
# Expected Value of Continuous Uniform Distribution: 0.5

# %%
# Q21: Compare the standard deviations of two datasets and visualize the difference
data1 = np.random.normal(0, 1, 1000)
data2 = np.random.normal(0, 2, 1000)
std1 = np.std(data1)
std2 = np.std(data2)
plt.bar(['Dataset 1', 'Dataset 2'], [std1, std2])
plt.title('Standard Deviation Comparison')
plt.ylabel('Standard Deviation')
plt.show()

# %%
# Q22: Calculate the range and interquartile range (IQR) of a dataset generated from a normal distribution
data = np.random.normal(0, 1, 1000)
data_range = np.max(data) - np.min(data)
q75, q25 = np.percentile(data, [75, 25])
iqr = q75 - q25
print("Range of the dataset:", data_range)
print("Interquartile Range (IQR):", iqr)
# Out:
# Range of the dataset: 6.514978410955397
# Interquartile Range (IQR): 1.4056551424929533

# %%
# Q23: Implement Z-score normalization on a dataset and visualize its transformation
data = np.random.normal(0, 1, 1000)
normalized_data = (data - np.mean(data)) / np.std(data)
plt.hist(normalized_data, bins=30, density=True, alpha=0.6, color='green')
plt.title('Z-Score Normalization')
plt.xlabel('Normalized Value')
plt.ylabel('Density')
plt.show()

# %%
# Q24: Calculate the skewness and kurtosis of a dataset generated from a normal distribution
from scipy.stats import skew, kurtosis
data = np.random.normal(0, 1, 1000)
data_skewness = skew(data)
data_kurtosis = kurtosis(data)
print("Skewness of the dataset:", data_skewness)
print("Kurtosis of the dataset:", data_kurtosis)
# Out:
# Skewness of the dataset: 0.0749078065581188
# Kurtosis of the dataset: -0.12366917829794888
